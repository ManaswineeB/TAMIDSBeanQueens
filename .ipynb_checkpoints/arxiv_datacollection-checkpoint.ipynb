# %% [markdown]
# ## Structure
# Below is the code I used to salvage the data from Arxiv.
# You don't need to run it. The data is collected and stored in the file 'arxived.txt'. Just run the cell below and it'll store the data in the list named 'arxiv_publications'.
# ## Cleanup needed
# The list it'll load will have repeated entries and it may even have some garbage data, namely some publincations listed there may be may be of someone not related to A&M. To cleanup the repeated entry I think you can make the list a set and then convert it back into a list, and that should remove repetations. To clean up the ghost entries, I don't know how I'd do that.

# %% [raw]
# ## This cell shows the code I used to collect and store the data
# import feedparser as fp
# import urllib
# import requests
# import string
# import json
# import time
# import unidecode
# def refine_texts(text):
#     text = unidecode.unidecode(text)
#     text = text.lower()
#     text = text.replace(',','')
#     for s in text:
#         if s not in string.ascii_lowercase+string.digits:
#             text = text.replace(s,' ')
#         else:
#             continue
#     return text.split()
#
# people = requests.get('https://api.library.tamu.edu/scholars-discovery/individual/n73bc0d79?fbclid=IwAR14AfAGbKtQYKRKPsaNcAdzvqQFt76bXYunrdSUMBxZXpGKC6yKxkcGQ4E').json()
# people = people['people']
# publication_data=[]
# for i in people:
#     url = 'https://api.library.tamu.edu/scholars-discovery/individual/'+i['id']
#     publication_data.append(requests.get(url).json())
#
# outfile = open('arxived.txt','r')
# arxiv_publications = json.loads(outfile.read())
# outfile.close()
# max_results = 3
# people_counter = 110
# for p in publication_data[people_counter:]:
#     if 'publications' in p.keys():
#         arxiv_url = 'http://export.arxiv.org/api/query?search_query='
#         name = refine_texts(p['name'])
#         last_name = 'au:%s'%name[0]
#         for publication in p['publications']:
#             title_url = '+AND+ti:'
#             title = refine_texts(publication['label'])
#             title_url+= title[0]
#             for j in title[1:10]:
#                 title_url+= '+AND+ti:%s'%j
#             webURL = arxiv_url+last_name+title_url
#             webURL+='&max_results=%i'%max_results
#             data = urllib.request.urlopen(arxiv_url+last_name+title_url).read()
#             feed = fp.parse(data)
#             arxiv_publications = arxiv_publications + feed['entries']
#             outfile = open('arxived.txt','w')
#             outfile.write(json.dumps(arxiv_publications))
#             outfile.close()
#             for i in feed['entries']:
#                 print(i['title']+'   %i\n'%people_counter)
#             time.sleep(4)
#         people_counter+= 1
#     else:
#         people_counter+= 1
#         continue

# %%
import json
with open('arxived.txt','r') as f:
    arxiv_publications = json.loads(f.read())
    f.close()

# %%
Categories = {
    "math.AG" : 'Algebraic Geometry',
    "math.AT" : 'Algebraic Topology',
    "math.AP" : 'Analysis of PDEs',
    "math.CT" : 'Category Theory',
    "math.CA" : 'Classical Analysis and ODEs',
    "math.CO" : 'Combinatorics',
    "math.AC" : 'Commutative Algebra',
    "math.CV" : 'Complex Variables',
    "math.DG" : 'Differential Geometry',
    "math.DS" : 'Dynamical Systems',
    "math.FA" : 'Functional Analysis',
    "math.GM" : 'General Math',
    "math.GN" : 'Genral Topology',
    "math.GT" : 'Geometric Topology',
    "math.GR" : 'Group Theory',
    "math.HO" : 'History and Overview',
    "math.IT" : 'Information Theory',
    "math.KT" : 'K-Theory and Homology',
    "math.LO" : 'Logic',
    "math.MP" : 'Mathematical Physics',
    "math.MG" : 'Metric Geometry',
    "math.NT" : 'Number Theory',
    "math.NA" : 'Numerical Analysis',
    "math.OA" : 'Operator Algebras',
    "math.OC" : 'Optimization and Control',
    "math.PR" : 'Probability',
    "math.QA" : 'Quantam Algebra',
    "math.RT" : 'Representation Theory',
    "math.RA" : 'Rings and Algebras',
    "math.SP" : 'Spectral Theory',
    "math.ST" : 'Statistics Theory',
    "math.SG" : 'Symplectic Geometry',
    "stat.AP" : 'Applications',
    "stat.CO" : 'Computation',
    "stat.ME" : 'Methodology',
    "stat.ML" : 'Machine Learning',
    "stst.OT" : 'Other Statistics',
    "stat.TH" : 'Statistics Theory',
    "cs.AI" : 'Artificial Intelligence',
    "cs.AR" : 'Hardware Architecture',
    "cs.CC" : 'Computational Complexity',
    "cs.CE" : 'Computational Engineering, Finance, and Science',
    "cs.CG" : 'Computational Geometry',
    "cs.CL" : 'Computation and Language',
    "cs.CR" : 'Cryptography and Security',
    "cs.CV" : 'Computer Vision and Pattern Recognition',
    "cs.CY" : 'Computers and Society',
    "cs.DB" : 'Databases',
    "cs.DC" : 'Distributed, Parallel, and Cluster Computing',
    "cs.DL" : 'Digital Libraries',
    "cs.DM" : 'Discrete Mathematics',
    "cs.DS" : 'Data Structures and Algorithms',
    "cs.ET" : 'Emerging Technologies',
    "cs.FL" : 'Formal Languages and Automata Theory',
    "cs.GL" : 'General Literature',
    "cs.GR" : 'Graphics',
    "cs.GT" : 'Computer Science and Game Theory',
    "cs.HC" : 'Human-Computer Interaction',
    "cs.IR" : 'Information Retrieval',
    "cs.IT" : 'Information Theory',
    "cs.LG" : 'Machine Learning',
    "cs.LO" : 'Logic in Computer Science',
    "cs.MA" : 'Multiagent Systems',
    "cs.MM" : 'Multimedia',
    "cs.MS" : 'Mathematical Software',
    "cs.NA" : 'Numerical Analysis',
    "cs.NE" : 'Neural and Evolutionary Computing',
    "cs.NI" : 'Network and Internet Architecture',
    "cs.OH" : 'Other Computer Science',
    "cs.OS" : 'Operating Systems',
    "cs.PF" : 'Performance',
    "cs.PL" : 'Programming Language',
    "cs.RO" : 'Robotics',
    "cs.SC" : 'Symbolic Computation',
    "cs.SD" : 'Sound',
    "cs.SE" : 'Software Engineering',
    "cs.SI" : 'Social and Information Networks',
    "cs.SY" : 'Systems and Control'
}

# %% [raw]
# #
# for article in arxiv_publications:
#     for i in range(len(article['tags'])):
#         if article['tags'][i]['term'] in Categories:
#             Categories[article['tags'][i]['term']].append(article['title'])
#
# #
# for cat in Categories.keys():
#     Categories[cat] = list(set(Categories[cat]))
#
# Categories['math.LO']

# %%
import feedparser as fp
import urllib
import requests
import string
import json
import time
import pandas as pd
import unidecode
def refine_texts(text):
    text = unidecode.unidecode(text)
    text = text.lower()
    text = text.replace(',','')
    for s in text:
        if s not in string.ascii_lowercase+string.digits:
            text = text.replace(s,' ')
        else:
            continue
    return text

# %%
df = pd.read_excel('Dimensions_ComSc_1.xlsx')
df.set_axis(df.iloc[0,:],axis=1,inplace=True)
df = df.drop(index=0,axis=1)

# %%
df.head()
# Out:
# 0 Rank  Publication ID                           DOI PMID PMCID  \
# 1  100  pub.1146383193    10.1016/j.xjep.2022.100514  NaN   NaN
# 2  100  pub.1146238473    10.1016/j.dche.2022.100020  NaN   NaN
# 3  100  pub.1144344439     10.1016/j.apm.2021.12.036  NaN   NaN
# 4  100  pub.1143225031               10.1145/3490176  NaN   NaN
# 5  100  pub.1146556931  10.1016/j.acalib.2022.102518  NaN   NaN
#
# 0                                              Title  \
# 1  A longitudinal model of communication networks...
# 2  Integration of surface-enhanced Raman spectros...
# 3  Non-dimensional analysis of the bandgap format...
# 4  Toward Taming the Overhead Monster for Data-fl...
# 5  OASES: The role of subject librarians in an ef...
#
# 0                                           Abstract  \
# 1  Background The Ryan White HIV/AIDS Program (RW...
# 2  Surface-enhanced Raman spectroscopy (SERS) is ...
# 3  The objective of this paper is to investigate ...
# 4  Data-Flow Integrity (DFI) is a well-known appr...
# 5  OASES (Open Access for Student Educational Suc...
#
# 0                                   Acknowledgements  \
# 1                                                NaN
# 2  This work was supported by the funds from Nati...
# 3  The authors gratefully acknowledge the support...
# 4                                                NaN
# 5                                                NaN
#
# 0                                       Source title Anthology title  ...  \
# 1  Journal of Interprofessional Education & Practice             NaN  ...
# 2                       Digital Chemical Engineering             NaN  ...
# 3                     Applied Mathematical Modelling             NaN  ...
# 4  ACM Transactions on Design Automation of Elect...             NaN  ...
# 5              The Journal of Academic Librarianship             NaN  ...
#
# 0                              Source Linkout  \
# 1                                         NaN
# 2  https://doi.org/10.1016/j.dche.2022.100020
# 3                                         NaN
# 4             http://arxiv.org/pdf/2102.10031
# 5                                         NaN
#
# 0                                     Dimensions URL  \
# 1  https://app.dimensions.ai/details/publication/...
# 2  https://app.dimensions.ai/details/publication/...
# 3  https://app.dimensions.ai/details/publication/...
# 4  https://app.dimensions.ai/details/publication/...
# 5  https://app.dimensions.ai/details/publication/...
#
# 0                            FOR (ANZSRC) Categories       RCDC Categories  \
# 1  08 Information and Computing Sciences; 0806 In...  HIV/AIDS; Prevention
# 2  08 Information and Computing Sciences; 09 Engi...        Bioengineering
# 3  08 Information and Computing Sciences; 0102 Ap...                   NaN
# 4  08 Information and Computing Sciences; 0803 Co...                   NaN
# 5  08 Information and Computing Sciences; 0807 Li...                   NaN
#
# 0 HRCS HC Categories HRCS RAC Categories ICRP Cancer Types  \
# 1                NaN                 NaN               NaN
# 2                NaN                 NaN               NaN
# 3                NaN                 NaN               NaN
# 4                NaN                 NaN               NaN
# 5                NaN                 NaN               NaN
#
# 0 ICRP CSO Categories                                Units of Assessment  \
# 1                 NaN  A02 Public Health, Health Services and Primary...
# 2                 NaN               B11 Computer Science and Informatics
# 3                 NaN                                    B12 Engineering
# 4                 NaN               B11 Computer Science and Informatics
# 5                 NaN                                      C23 Education
#
# 0 Sustainable Development Goals
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
#
# [5 rows x 49 columns]

# %%
outfile = open('dimensions_arxiv_cs1.txt','r')
arxiv_publications = []
outfile.close()
max_results = 4
for i in range(1137,df.shape[0]):
    arxiv_url = 'http://export.arxiv.org/api/query?search_query='
    name = refine_texts(df['Authors'][i]).split()
    last_name = 'au:%s'%name[0]
    title_url = '+AND+ti:'
    title = refine_texts(df['Title'][i]).split()
    title_url+= title[0]
    for j in title[1:5]:
        title_url+= '+AND+ti:%s'%j
    webURL = arxiv_url+last_name+title_url
    webURL+='&max_results=%i'%max_results
    data = urllib.request.urlopen(webURL).read()
    feed = fp.parse(data)
    arxiv_publications = arxiv_publications + feed['entries']
    outfile = open('dimensions_arxiv_cs1.txt','w')
    outfile.write(json.dumps(arxiv_publications))
    outfile.close()
    for pub in feed['entries']:
        print(pub['title']+'   %i\n'%i)
    time.sleep(6)
# Out:
# Vehicular Teamwork: Collaborative localization of Autonomous Vehicles   588
#
# Decontextualized learning for interpretable hierarchical representations
#   of visual patterns   590
#
# New Results on the Storage-Retrieval Tradeoff in Private Information
#   Retrieval Systems   591
#
# Graph-based Proprioceptive Localization Using a Discrete Heading-Length
#   Feature Sequence Matching Approach   594
#
# Net2: A Graph Attention Network Method Customized for Pre-Placement Net
#   Length Estimation   598
#
# Techniques for Automated Machine Learning   600
#
# Generalized Iris Presentation Attack Detection Algorithm under
#   Cross-Database Settings   602
#
# Attack Agnostic Adversarial Defense via Visual Imperceptible Bound   603
#
# MixNet for Generalized Face Presentation Attack Detection   604
#
# Autonomous Visual Assistance for Robot Operations Using a Tethered UAV   606
#
# Infinite Families of Quantum-Classical Hybrid Codes   608
#
# Joint Index Coding and Incentive Design for Selfish Clients   614
#
# Hybrid RF/VLC Systems: A Comprehensive Survey on Network Topologies,
#   Performance Analyses, Applications, and Future Directions   620
#
# A Localization and Navigation Method for an In-pipe Robot in Water
#   Distribution System through Wireless Control towards Long-Distance Inspection   626
#
# FloodNet: A High Resolution Aerial Imagery Dataset for Post Flood Scene
#   Understanding   630
#
# Non-invasive assessment of the spatial and temporal distributions of
#   interstitial fluid pressure, fluid velocity and fluid flow in cancers in vivo   631
#
# Quantifying the multi-objective cost of uncertainty   633
#
# Collaborative Localization for Micro Aerial Vehicles   635
#
# Monocular Vision based Collaborative Localization for Micro Aerial
#   Vehicle Swarms   635
#
# Optimal Experimental Design for Uncertain Systems Based on Coupled
#   Differential Equations   638
#
# Accelerating Optimal Experimental Design for Robust Synchronization of
#   Uncertain Kuramoto Oscillator Model Using Machine Learning   638
#
# Detecting Early-warning signals in Time Series of Visits to Points of
#   Interests to Examine Population Response to COVID -19 Pandemic   642
#
# A Hybrid BERT and LightGBM based Model for Predicting Emotion GIF
#   Categories on Twitter   643
#
# Predicting commuter flows in spatial networks using a radiation model
#   based on temporal ranges   643
#
# A High Accuracy Electrical Stopping Power Prediction Model based on Deep
#   Learning Algorithm and its Applications   643
#
# OnionNet-2: A Convolutional Neural Network Model for Predicting
#   Protein-Ligand Binding Affinity based on Residue-Atom Contacting Shells   643
#
# UNSAIL: Thwarting Oracle-Less Machine Learning Attacks on Logic Locking   644
#
# Bypassing the computational bottleneck of quantum-embedding theories for
#   strong electron correlations with machine learning   645
#
# Sub-optimal Tracking in Switched Systems with Controlled Subsystems and
#   Fixed-mode Sequence using Approximate Dynamic Programming   653
#
# Inline Vector Compression for Computational Physics   654
#
# Age of Information for Single Buffer Systems with Vacation Server   656
#
# Robust Importance Sampling for Error Estimation in the Context of
#   Optimal Bayesian Transfer Learning   668
#
# Few-shot Learning in Emotion Recognition of Spontaneous Speech Using a
#   Siamese Neural Network with Adaptive Sample Pair Formation   671
#
# Computing Essential Sets for Convex and Non-convex Scenario Problems:
#   Theory and Application   674
#
# String Stability of Connected Vehicle Platoons under Lossy V2V
#   Communication   677
#
# EMU: Efficient Muscle Simulation In Deformation Space   685
#
# Explainable Deep Relational Networks for Predicting Compound-Protein
#   Affinities and Contacts   689
#
# Utility of Traffic Information in Dynamic Routing: Is Sharing
#   Information Always Useful?   697
#
# Comprehensive Semantic Segmentation on High Resolution UAV Imagery for
#   Natural Disaster Damage Assessment   704
#
# Botnet Detection Using Recurrent Variational Autoencoder   713
#
# GIF: Generative Interpretable Faces   734
#
# Distributed Mirror Descent with Integral Feedback: Asymptotic
#   Convergence Analysis of Continuous-time Dynamics   736
#
# Linear Convergence of Distributed Mirror Descent with Integral Feedback
#   for Strongly Convex Problems   736
#
# Combining Recurrent Neural Networks and Adversarial Training for Human
#   Motion Synthesis and Control   739
#
# Consistent estimation of the max-flow problem: Towards unsupervised
#   image segmentation   740
#
# CorDEL: A Contrastive Deep Learning Approach for Entity Linkage   745
#
# On the Fundamental Limits of Coded Caching Systems with Restricted
#   Demand Types   753
#
# An Iterative LQR Controller for Off-Road and On-Road Vehicles using a
#   Neural Network Dynamics Model   759
#
# AutoCone: An OmniDirectional Robot for Lane-Level Cone Placement   761
#
# Peeking into occluded joints: A novel framework for crowd pose
#   estimation   763
#
# The Joint Automated Repository for Various Integrated Simulations
#   (JARVIS) for data-driven materials design   767
#
# Deep Reinforcement Learning for Electric Transmission Voltage Control   769
#
# Translating Math Formula Images to LaTeX Sequences Using Deep Neural
#   Networks with Sequence-level Training   786
#
# Cell Association via Boundary Detection: A Scalable Approach Based on
#   Data-Driven Random Features   791
#
# A Survey of Cybersecurity of Digital Manufacturing   793
#
# Learning-based Dynamic Cache Management in a Cloud   797
#
# DRCAS: Deep Restoration Network for Hardware Based Compressive
#   Acquisition Scheme   807
#
# Peak Age of Information in Priority Queueing Systems   809
#
# On Peak Age of Information in Data Preprocessing enabled IoT Networks   809
#
# Computability, orders, and solvable groups   816
#
# Romeo: A Design Tool for Embedding Transformable Parts in 3D Models to
#   Robotically Augment Default Functionalities   823
#
# Extrinsic Calibration of a 3D-LIDAR and a Camera   824
#
# Target-free Extrinsic Calibration of a 3D-Lidar and an IMU   824
#
# Graph Prototypical Networks for Few-shot Learning on Attributed Networks   826
#
# Explainable Recommender Systems via Resolving Learning Representations   827
#
# Towards Generalizable Deepfake Detection with Locality-aware AutoEncoder   828
#
# Remote Control: A Simple Deadlock Avoidance Scheme for Modular System on
#   Chip   838
#
# Enhanced Normalized Mutual Information for Localization in Noisy
#   Environments   840
#
# Distributed Networked Real-time Learning   841
#
# The Role of Coded Side Information in Single-Server Private Information
#   Retrieval   843
#
# AutoRec: An Automated Recommender System   867
#
# Machine learning in physics: The pitfalls of poisoned training sets   873
#
# Fast Local Planning and Mapping in Unknown Off-Road Terrain   882
#
# Abstractions for computing all robotic sensors that suffice to solve a
#   planning problem   883
#
# DeepCOVIDNet: An Interpretable Deep Learning Model for Predictive
#   Surveillance of COVID-19 Using Heterogeneous Features and their Interactions   887
#
# Decontextualized learning for interpretable hierarchical representations
#   of visual patterns   891
#
# Deep Learning of High-Order Interactions for Protein Interface
#   Prediction   896
#
# Towards Automated Neural Interaction Discovery for Click-Through Rate
#   Prediction   897
#
# XGNN: Towards Model-Level Explanations of Graph Neural Networks   899
#
# An Embarrassingly Simple Approach for Knowledge Distillation   900
#
# An Embarrassingly Simple Approach for Trojan Attack in Deep Neural
#   Networks   900
#
# Towards Deeper Graph Neural Networks   901
#
# Kronecker Attention Networks   902
#
# On the Storage Cost of Private Information Retrieval   911
#
# Change detection in complex dynamical systems using intrinsic phase and
#   amplitude synchronization   913
#
# Developing Personalized Models of Blood Pressure Estimation from
#   Wearable Sensors Data Using Minimally-trained Domain Adversarial Neural
#   Networks   921
#
# Improving Uncertainty of Deep Learning-based Object Classification on
#   Radar Spectra using Label Smoothing   926
#
# Investigation of Uncertainty of Deep Learning-based Object
#   Classification on Radar Spectra   926
#
# A Coded Compressed Sensing Scheme for Uncoordinated Multiple Access   927
#
# Bounded Regret for Finitely Parameterized Multi-Armed Bandits   951
#
# Hyperspectral imaging for dynamic thin film interferometry   956
# Predictive Scheduling for Virtual Reality   958
#
# Utility and Privacy in Object Tracking from Video Stream using Kalman
#   Filter   960
#
# Nonlinear Attitude Estimation for Small UAVs with Low Power
#   Microprocessors   968
#
# Distributed Parameter Estimation in Randomized One-hidden-layer Neural
#   Networks   970
#
# Network-principled deep generative models for designing drug
#   combinations as graph sets   977
#
# CodNN -- Robust Neural Networks From Coded Classification   991
#
# Factored LT and Factored Raptor Codes for Large-Scale Distributed Matrix
#   Multiplication   994
#
# On the Information Leakage in Private Information Retrieval Systems   995
#
# On the Storage Cost of Private Information Retrieval   996
#
# Private Computation with Individual and Joint Privacy   998
#
# Multi-Server Private Linear Computation with Joint and Individual
#   Privacy Guarantees   998
#
# On Approximate Message Passing for Unsourced Access with Coded
#   Compressed Sensing   1000
#
# Weakly Secure Symmetric Multilevel Diversity Coding   1004
#
# Bayesian active learning for optimization and uncertainty quantification
#   in protein docking   1005
#
# Polar Coding and Random Spreading for Unsourced Multiple Access   1012
#
# Cost-aware Cascading Bandits   1013
#
# Fairness in Deep Learning: A Computational Perspective   1014
#
# AdaDeep: A Usage-Driven, Automated Deep Model Compression Framework for
#   Enabling Ubiquitous Intelligent Mobiles   1016
#
# Second-Order Pooling for Graph Neural Networks   1020
#
# Non-dimensional Star-Identification   1038
#
# Finding plans subject to stipulations on what information they divulge   1042
#
# An enhanced decoding algorithm for coded compressed sensing   1044
#
# An Enhanced Decoding Algorithm for Coded Compressed Sensing with
#   Applications to Unsourced Random Access   1044
#
# Attention Mechanism Enhanced Kernel Prediction Networks for Denoising of
#   Burst Images   1045
#
# ARSM Gradient Estimator for Supervised Learning to Rank   1046
#
# Learning Algorithms for Coarsening Uncertainty Space and Applications to
#   Multiscale Simulations   1051
#
# Functional Error Correction for Robust Neural Networks   1054
#
# On Scheduling Two-Stage Jobs on Multiple Two-Stage Flowshops   1056
#
# Combining Visible and Infrared Spectrum Imagery using Machine Learning
#   for Small Unmanned Aerial System Detection   1057
#
# Secure Erasure Codes With Partial Decodability   1064
#
# Deep Slow Motion Video Reconstruction with Hybrid Imaging System   1065
#
# Economic Evaluation of Transformer Loss of Life Mitigation by Energy
#   Storage and PV Generation   1066
#
# Nonbinary Error-Detecting Hybrid Codes   1078
#
# UG$^{2+}$ Track 2: A Collective Benchmark Effort for Evaluating and
#   Advancing Image Understanding in Poor Visibility Environments   1087
#
# Energy-based Graph Convolutional Networks for Scoring Protein Docking
#   Models   1096
#
# Dual Dynamic Inference: Enabling More Efficient, Adaptive and
#   Controllable Deep Inference   1104
#
# Calibrated Domain-Invariant Learning for Highly Generalizable Large
#   Scale Re-Identification   1107
#
# Capacity-Achieving Private Information Retrieval Codes from MDS-Coded
#   Databases with Minimum Message Size   1119
#
# Network estimation via graphon with node features   1125
#
# Numerical Software to Compute Newton Polytopes and Tropical Membership   1131
#
# Coherency Detection and Network Partitioning based on Hierarchical
#   DBSCAN   1133
#
# Constraint Clustering Based Islanding Scheme For Power Networks   1136
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-979211ce522b> in <module>
#      14     webURL = arxiv_url+last_name+title_url
#      15     webURL+='&max_results=%i'%max_results
# ---> 16     data = urllib.request.urlopen(webURL).read()
#      17     feed = fp.parse(data)
#      18     arxiv_publications = arxiv_publications + feed['entries']
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\anaconda3\lib\urllib\request.py in http_open(self, req)
#    1377
#    1378     def http_open(self, req):
# -> 1379         return self.do_open(http.client.HTTPConnection, req)
#    1380
#    1381     http_request = AbstractHTTPHandler.do_request_
#
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1352             except OSError as err: # timeout error
#    1353                 raise URLError(err)
# -> 1354             r = h.getresponse()
#    1355         except:
#    1356             h.close()
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# #### arxiv_pub_id = []
# arxiv_pubs_clean = []
# for i in arxiv_publications:
#     if i['id'] not in arxiv_pub_id:
#         arxiv_pubs_clean.append(i)
#         arxiv_pub_id.append(i['id'])
# vizfile = open('vizfile_2.ris','w')
# for article in arxiv_pubs_clean:
#     vizfile.write('\nTY  - JOUR')
#     Author = refine_texts(article['author'])
#     vizfile.write('\nAU  - %s'%Author)
#     vizfile.write('\nPY  - %s'%article['published'][:4])
#     Title = refine_texts(article['title'])
#     vizfile.write('\nTI  - %s'%Title)
#     for tags in article['tags']:
#         if tags['term'] in Categories.keys():
#             vizfile.write('\nKW  - %s'%Categories[tags['term']])
#         else:
#             continue
#     vizfile.write('\nER  - \n')
# vizfile.close()
