# %% [markdown]
# ## Structure
# Below is the code I used to salvage the data from Arxiv.
# You don't need to run it. The data is collected and stored in the file 'arxived.txt'. Just run the cell below and it'll store the data in the list named 'arxiv_publications'.
# ## Cleanup needed
# The list it'll load will have repeated entries and it may even have some garbage data, namely some publincations listed there may be may be of someone not related to A&M. To cleanup the repeated entry I think you can make the list a set and then convert it back into a list, and that should remove repetations. To clean up the ghost entries, I don't know how I'd do that.

# %% [raw]
# ## This cell shows the code I used to collect and store the data
# import feedparser as fp
# import urllib
# import requests
# import string
# import json
# import time
# import unidecode
# def refine_texts(text):
#     text = unidecode.unidecode(text)
#     text = text.lower()
#     text = text.replace(',','')
#     for s in text:
#         if s not in string.ascii_lowercase+string.digits:
#             text = text.replace(s,' ')
#         else:
#             continue
#     return text.split()
#
# people = requests.get('https://api.library.tamu.edu/scholars-discovery/individual/n73bc0d79?fbclid=IwAR14AfAGbKtQYKRKPsaNcAdzvqQFt76bXYunrdSUMBxZXpGKC6yKxkcGQ4E').json()
# people = people['people']
# publication_data=[]
# for i in people:
#     url = 'https://api.library.tamu.edu/scholars-discovery/individual/'+i['id']
#     publication_data.append(requests.get(url).json())
#
# outfile = open('arxived.txt','r')
# arxiv_publications = json.loads(outfile.read())
# outfile.close()
# max_results = 3
# people_counter = 110
# for p in publication_data[people_counter:]:
#     if 'publications' in p.keys():
#         arxiv_url = 'http://export.arxiv.org/api/query?search_query='
#         name = refine_texts(p['name'])
#         last_name = 'au:%s'%name[0]
#         for publication in p['publications']:
#             title_url = '+AND+ti:'
#             title = refine_texts(publication['label'])
#             title_url+= title[0]
#             for j in title[1:10]:
#                 title_url+= '+AND+ti:%s'%j
#             webURL = arxiv_url+last_name+title_url
#             webURL+='&max_results=%i'%max_results
#             data = urllib.request.urlopen(arxiv_url+last_name+title_url).read()
#             feed = fp.parse(data)
#             arxiv_publications = arxiv_publications + feed['entries']
#             outfile = open('arxived.txt','w')
#             outfile.write(json.dumps(arxiv_publications))
#             outfile.close()
#             for i in feed['entries']:
#                 print(i['title']+'   %i\n'%people_counter)
#             time.sleep(4)
#         people_counter+= 1
#     else:
#         people_counter+= 1
#         continue

# %%
import json
with open('arxived.txt','r') as f:
    arxiv_publications = json.loads(f.read())
    f.close()

# %%
Categories = {
    "math.AG" : 'Algebraic Geometry',
    "math.AT" : 'Algebraic Topology',
    "math.AP" : 'Analysis of PDEs',
    "math.CT" : 'Category Theory',
    "math.CA" : 'Classical Analysis and ODEs',
    "math.CO" : 'Combinatorics',
    "math.AC" : 'Commutative Algebra',
    "math.CV" : 'Complex Variables',
    "math.DG" : 'Differential Geometry',
    "math.DS" : 'Dynamical Systems',
    "math.FA" : 'Functional Analysis',
    "math.GM" : 'General Math',
    "math.GN" : 'Genral Topology',
    "math.GT" : 'Geometric Topology',
    "math.GR" : 'Group Theory',
    "math.HO" : 'History and Overview',
    "math.IT" : 'Information Theory',
    "math.KT" : 'K-Theory and Homology',
    "math.LO" : 'Logic',
    "math.MP" : 'Mathematical Physics',
    "math.MG" : 'Metric Geometry',
    "math.NT" : 'Number Theory',
    "math.NA" : 'Numerical Analysis',
    "math.OA" : 'Operator Algebras',
    "math.OC" : 'Optimization and Control',
    "math.PR" : 'Probability',
    "math.QA" : 'Quantam Algebra',
    "math.RT" : 'Representation Theory',
    "math.RA" : 'Rings and Algebras',
    "math.SP" : 'Spectral Theory',
    "math.ST" : 'Statistics Theory',
    "math.SG" : 'Symplectic Geometry',
    "stat.AP" : 'Applications',
    "stat.CO" : 'Computation',
    "stat.ME" : 'Methodology',
    "stat.ML" : 'Machine Learning',
    "stst.OT" : 'Other Statistics',
    "stat.TH" : 'Statistics Theory',
    "cs.AI" : 'Artificial Intelligence',
    "cs.AR" : 'Hardware Architecture',
    "cs.CC" : 'Computational Complexity',
    "cs.CE" : 'Computational Engineering, Finance, and Science',
    "cs.CG" : 'Computational Geometry',
    "cs.CL" : 'Computation and Language',
    "cs.CR" : 'Cryptography and Security',
    "cs.CV" : 'Computer Vision and Pattern Recognition',
    "cs.CY" : 'Computers and Society',
    "cs.DB" : 'Databases',
    "cs.DC" : 'Distributed, Parallel, and Cluster Computing',
    "cs.DL" : 'Digital Libraries',
    "cs.DM" : 'Discrete Mathematics',
    "cs.DS" : 'Data Structures and Algorithms',
    "cs.ET" : 'Emerging Technologies',
    "cs.FL" : 'Formal Languages and Automata Theory',
    "cs.GL" : 'General Literature',
    "cs.GR" : 'Graphics',
    "cs.GT" : 'Computer Science and Game Theory',
    "cs.HC" : 'Human-Computer Interaction',
    "cs.IR" : 'Information Retrieval',
    "cs.IT" : 'Information Theory',
    "cs.LG" : 'Machine Learning',
    "cs.LO" : 'Logic in Computer Science',
    "cs.MA" : 'Multiagent Systems',
    "cs.MM" : 'Multimedia',
    "cs.MS" : 'Mathematical Software',
    "cs.NA" : 'Numerical Analysis',
    "cs.NE" : 'Neural and Evolutionary Computing',
    "cs.NI" : 'Network and Internet Architecture',
    "cs.OH" : 'Other Computer Science',
    "cs.OS" : 'Operating Systems',
    "cs.PF" : 'Performance',
    "cs.PL" : 'Programming Language',
    "cs.RO" : 'Robotics',
    "cs.SC" : 'Symbolic Computation',
    "cs.SD" : 'Sound',
    "cs.SE" : 'Software Engineering',
    "cs.SI" : 'Social and Information Networks',
    "cs.SY" : 'Systems and Control'
}

# %% [raw]
# #
# for article in arxiv_publications:
#     for i in range(len(article['tags'])):
#         if article['tags'][i]['term'] in Categories:
#             Categories[article['tags'][i]['term']].append(article['title'])
#
# #
# for cat in Categories.keys():
#     Categories[cat] = list(set(Categories[cat]))
#
# Categories['math.LO']

# %%
import feedparser as fp
import urllib
import requests
import string
import json
import time
import pandas as pd
import unidecode
def refine_texts(text):
    text = unidecode.unidecode(text)
    text = text.lower()
    text = text.replace(',','')
    for s in text:
        if s not in string.ascii_lowercase+string.digits:
            text = text.replace(s,' ')
        else:
            continue
    return text

# %%
df = pd.read_excel('Dimensions_ComSc_1.xlsx')
df.set_axis(df.iloc[0,:],axis=1,inplace=True)
df = df.drop(index=0,axis=1)

# %%
df.head()
# Out:
# 0 Rank  Publication ID                           DOI PMID PMCID  \
# 1  100  pub.1146383193    10.1016/j.xjep.2022.100514  NaN   NaN
# 2  100  pub.1146238473    10.1016/j.dche.2022.100020  NaN   NaN
# 3  100  pub.1144344439     10.1016/j.apm.2021.12.036  NaN   NaN
# 4  100  pub.1143225031               10.1145/3490176  NaN   NaN
# 5  100  pub.1146556931  10.1016/j.acalib.2022.102518  NaN   NaN
#
# 0                                              Title  \
# 1  A longitudinal model of communication networks...
# 2  Integration of surface-enhanced Raman spectros...
# 3  Non-dimensional analysis of the bandgap format...
# 4  Toward Taming the Overhead Monster for Data-fl...
# 5  OASES: The role of subject librarians in an ef...
#
# 0                                           Abstract  \
# 1  Background The Ryan White HIV/AIDS Program (RW...
# 2  Surface-enhanced Raman spectroscopy (SERS) is ...
# 3  The objective of this paper is to investigate ...
# 4  Data-Flow Integrity (DFI) is a well-known appr...
# 5  OASES (Open Access for Student Educational Suc...
#
# 0                                   Acknowledgements  \
# 1                                                NaN
# 2  This work was supported by the funds from Nati...
# 3  The authors gratefully acknowledge the support...
# 4                                                NaN
# 5                                                NaN
#
# 0                                       Source title Anthology title  ...  \
# 1  Journal of Interprofessional Education & Practice             NaN  ...
# 2                       Digital Chemical Engineering             NaN  ...
# 3                     Applied Mathematical Modelling             NaN  ...
# 4  ACM Transactions on Design Automation of Elect...             NaN  ...
# 5              The Journal of Academic Librarianship             NaN  ...
#
# 0                              Source Linkout  \
# 1                                         NaN
# 2  https://doi.org/10.1016/j.dche.2022.100020
# 3                                         NaN
# 4             http://arxiv.org/pdf/2102.10031
# 5                                         NaN
#
# 0                                     Dimensions URL  \
# 1  https://app.dimensions.ai/details/publication/...
# 2  https://app.dimensions.ai/details/publication/...
# 3  https://app.dimensions.ai/details/publication/...
# 4  https://app.dimensions.ai/details/publication/...
# 5  https://app.dimensions.ai/details/publication/...
#
# 0                            FOR (ANZSRC) Categories       RCDC Categories  \
# 1  08 Information and Computing Sciences; 0806 In...  HIV/AIDS; Prevention
# 2  08 Information and Computing Sciences; 09 Engi...        Bioengineering
# 3  08 Information and Computing Sciences; 0102 Ap...                   NaN
# 4  08 Information and Computing Sciences; 0803 Co...                   NaN
# 5  08 Information and Computing Sciences; 0807 Li...                   NaN
#
# 0 HRCS HC Categories HRCS RAC Categories ICRP Cancer Types  \
# 1                NaN                 NaN               NaN
# 2                NaN                 NaN               NaN
# 3                NaN                 NaN               NaN
# 4                NaN                 NaN               NaN
# 5                NaN                 NaN               NaN
#
# 0 ICRP CSO Categories                                Units of Assessment  \
# 1                 NaN  A02 Public Health, Health Services and Primary...
# 2                 NaN               B11 Computer Science and Informatics
# 3                 NaN                                    B12 Engineering
# 4                 NaN               B11 Computer Science and Informatics
# 5                 NaN                                      C23 Education
#
# 0 Sustainable Development Goals
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
#
# [5 rows x 49 columns]

# %%
outfile = open('dimensions_arxiv_cs1.txt','r')
arxiv_publications = []
outfile.close()
max_results = 4
for i in range(1137,df.shape[0]):
    arxiv_url = 'http://export.arxiv.org/api/query?search_query='
    name = refine_texts(df['Authors'][i]).split()
    last_name = 'au:%s'%name[0]
    title_url = '+AND+ti:'
    title = refine_texts(df['Title'][i]).split()
    title_url+= title[0]
    for j in title[1:5]:
        title_url+= '+AND+ti:%s'%j
    webURL = arxiv_url+last_name+title_url
    webURL+='&max_results=%i'%max_results
    data = urllib.request.urlopen(webURL).read()
    feed = fp.parse(data)
    arxiv_publications = arxiv_publications + feed['entries']
    outfile = open('dimensions_arxiv_cs1.txt','w')
    outfile.write(json.dumps(arxiv_publications))
    outfile.close()
    for pub in feed['entries']:
        print(pub['title']+'   %i\n'%i)
    time.sleep(6)
# Out:
# Efficient Bayesian shape-restricted function estimation with constrained
#   Gaussian process priors   1145
#
# Multi-Temporal Analysis and Scaling Relations of 100,000,000,000 Network
#   Packets   1149
#
# Finer Metagenomic Reconstruction via Biodiversity Optimization   1152
#
# Mobility and Safety Benefits of Connectivity in CACC Vehicle Strings   1153
#
# Global Pixel Transformers for Virtual Staining of Microscopy Images   1160
#
# Consistency-Aware Recommendation for User-Generated ItemList
#   Continuation   1164
#
# DADA: Deep Adversarial Data Augmentation for Extremely Low Data Regime
#   Classification   1165
#
# Connecting Image Denoising and High-Level Vision Tasks via Deep Learning   1168
#
# Effective Super-Resolution Method for Paired Electron Microscopic Images   1195
#
# Energy and Information Management of Electric Vehicular Network: A
#   Survey   1199
#
# On the Information Leakage in Private Information Retrieval Systems   1200
#
# Quantile Graphical Models: Bayesian Approaches   1213
#
# WaveTransform: Crafting Adversarial Examples via Input Decomposition   1218
#
# Explainable Deep Relational Networks for Predicting Compound-Protein
#   Affinities and Contacts   1236
#
# Remarks on the Rényi Entropy of a sum of IID random variables   1239
#
# Techniques for Interpretable Machine Learning   1241
#
# Energy-based Graph Convolutional Networks for Scoring Protein Docking
#   Models   1242
#
# The Trade-off between Privacy and Fidelity via Ehrhart Theory   1244
#
# Impossibility of dimension reduction in the nuclear norm   1246
#
# Piecewise Stationary Modeling of Random Processes Over Graphs With an
#   Application to Traffic Prediction   1251
#
# A Mean Field Game Approach to Scheduling in Cellular Systems   1253
#
# Sparse IDMA: A Joint Graph-Based Coding Scheme for Unsourced Random
#   Access   1256
#
# Artificial neural network to estimate the refractive index of a liquid
#   infiltrating a chiral sculptured thin film   1266
#
# Theoretical Limits of Star Sensor Accuracy   1269
#
# Dilated Fully Convolutional Neural Network for Depth Estimation from a
#   Single Image   1270
#
# Network Topology Mapping from Partial Virtual Coordinates and Graph
#   Geodesics   1273
#
# Network Topology Mapping from Partial Virtual Coordinates and Graph
#   Geodesics   1273
#
# Semi-Semantic Line-Cluster Assisted Monocular SLAM for Indoor
#   Environments   1285
#
# General Linear Group Action on Tensors: A Candidate for Post-Quantum
#   Cryptography   1288
#
# Threshold Logic in a Flash   1290
#
# Learning Credible Deep Neural Networks with Rationale Regularization   1307
#
# Distributed Fictitious Play in Potential Games with Time-Varying
#   Communication Networks   1319
#
# SpecAE: Spectral AutoEncoder for Anomaly Detection in Attributed
#   Networks   1325
#
# A Hierarchical Self-Attentive Model for Recommending User-Generated Item
#   Lists   1328
#
# AutoGAN: Neural Architecture Search for Generative Adversarial Networks   1330
#
# Key-agreement based on automaton groups   1347
#
# Private Information Retrieval with Side Information   1349
#
# On the Capacity of Single-Server Multi-Message Private Information
#   Retrieval with Side Information   1349
#
# Single-Server Multi-Message Individually-Private Information Retrieval
#   with Side Information   1349
#
# The Explicit Coding Rate Region of Symmetric Multilevel Diversity Coding   1364
#
# ScanSAT: Unlocking Static and Dynamic Scan Obfuscation   1396
#
# A game method for improving the interpretability of convolution neural
#   network   1401
#
# Short-term origin-destination demand prediction in urban rail transit
#   systems: A channel-wise attentive split-convolutional neural network method   1401
#
# A Combined Data-driven and Physics-driven Method for Steady Heat
#   Conduction Prediction using Deep Convolutional Neural Networks   1401
#
# Sparse Graph Codes for Non-adaptive Quantitative Group Testing   1409
#
# On the Fundamental Limits of Coded Caching Systems with Restricted
#   Demand Types   1410
#
# Collaborative Decoding of Polynomial Codes for Distributed Computation   1411
#
# Weakly Secure Symmetric Multilevel Diversity Coding   1412
#
# On an Equivalence Between Single-Server PIR with Side Information and
#   Locally Recoverable Codes   1413
#
# Breaking the MDS-PIR Capacity Barrier via Joint Storage Coding   1417
#
# Frank-Wolfe Network: An Interpretable Deep Structure for Non-Sparse
#   Coding   1421
#
# Experience Replay Optimization   1443
#
# Is a Single Vector Enough? Exploring Node Polysemy for Network Embedding   1450
#
# Coupled Variational Recurrent Collaborative Filtering   1453
#
# Unsupervised Representation Adversarial Learning Network: from
#   Reconstruction to Generation   1454
#
# Learning Constitutive Relations from Indirect Observations Using Deep
#   Neural Networks   1454
#
# Soft Sensing Model Visualization: Fine-tuning Neural Network from What
#   Model Learned   1454
#
# CANZSL: Cycle-Consistent Adversarial Networks for Zero-Shot Learning
#   from Natural Language   1454
#
# Attention based Broadly Self-guided Network for Low light Image
#   Enhancement   1459
#
# Deep Structured Cross-Modal Anomaly Detection   1460
#
# Deep Recurrent Electricity Theft Detection in AMI Networks with Random
#   Tuning of Hyper-parameters   1465
#
# Single-Server Single-Message Online Private Information Retrieval with
#   Side Information   1470
#
# The Linear Capacity of Single-Server Individually-Private Information
#   Retrieval with Side Information   1471
#
# Capacity of Single-Server Single-Message Private Information Retrieval
#   with Coded Side Information   1471
#
# Capacity of Single-Server Single-Message Private Information Retrieval
#   with Private Coded Side Information   1471
#
# On the Capacity of Single-Server Multi-Message Private Information
#   Retrieval with Side Information   1471
#
# Capacity-Achieving Private Information Retrieval Codes from MDS-Coded
#   Databases with Minimum Message Size   1472
#
# Single-Server Multi-Message Individually-Private Information Retrieval
#   with Side Information   1474
#
# A Faster Solution to Smale's 17th Problem I: Real Binomial Systems   1478
#
# A new and flexible method for constructing designs for computer
#   experiments   1479
#
# Convolutional LSTM Network: A Machine Learning Approach for
#   Precipitation Nowcasting   1487
#
# Iterative Hard Thresholding for Low-Rank Recovery from Rank-One
#   Projections   1490
#
# On Scheduling Two-Stage Jobs on Multiple Two-Stage Flowshops   1491
#
# Collaborative Global-Local Networks for Memory-Efficient Segmentation of
#   Ultra-High Resolution Images   1503
#
# Scalable optimal Bayesian classification of single-cell trajectories
#   under regulatory model uncertainty   1509
#
# Automated Activity Recognition of Construction Equipment Using a Data
#   Fusion Approach   1520
#
# Learned Robust PCA: A Scalable Deep Unfolding Approach for
#   High-Dimensional Outlier Detection   1529
#
# Predicting Channel Quality Indicators for 5G Downlink Scheduling in a
#   Deep Learning Approach   1529
#
# Multi-Server Private Information Retrieval with Coded Side Information   1533
#
# Private Information Retrieval with Private Coded Side Information: The
#   Multi-Server Case   1533
#
# Cache-Version Selection and Content Placement for Adaptive Video
#   Streaming in Wireless Edge Networks   1535
#
# SimDoc: Topic Sequence Alignment based Document Similarity Framework   1538
#
# ALIGN: A System for Automating Analog Layout   1538
#
# Gaussian Processes Model-based Control of Underactuated Balance Robots   1559
#
# Gaussian Process-Based Model Predictive Control for Overtaking   1559
#
# Representation-Oblivious Error Correction by Natural Redundancy   1561
#
# Capacity-Achieving Private Information Retrieval Codes with Optimal
#   Message Size and Upload Cost   1562
#
# Capacity-Achieving Private Information Retrieval Codes from MDS-Coded
#   Databases with Minimum Message Size   1562
#
# Capacity-Achieving Private Information Retrieval Codes with Optimal
#   Message Size and Upload Cost   1565
#
# Capacity-Achieving Private Information Retrieval Codes from MDS-Coded
#   Databases with Minimum Message Size   1565
#
# Synthetic Dynamic PMU Data Generation: A Generative Adversarial Network
#   Approach   1568
#
# RedisGraph GraphBLAS Enabled Graph Database   1572
#
# An Efficient One-Class SVM for Anomaly Detection in the Internet of
#   Things   1580
#
# Prediction of Discretization of GMsFEM using Deep Learning   1591
#
# Codes with Locality in the Rank and Subspace Metrics   1592
# Physics-Inspired Optimization for Quadratic Unconstrained Problems Using
#   a Digital Annealer   1618
#
# Deep Representation Learning for Social Network Analysis   1619
#
# Enhance Visual Recognition under Adverse Conditions via Deep Networks   1624
#
# Convolutional Sparse Coding for Compressed Sensing CT Reconstruction   1637
#
# Adaptive Group-based Zero Knowledge Proof-Authentication Protocol
#   (AGZKP-AP) in Vehicular Ad Hoc Networks   1647
#
# A very brief introduction to quantum computing and quantum information
#   theory for mathematicians   1648
#
# Implementing $\Diamond P$ with Bounded Messages on a Network of ADD
#   Channels   1663
#
# Nonparametric Operator-Regularized Covariance Function Estimation for
#   Functional Data   1673
#
# Learning Simple Thresholded Features with Sparse Support Recovery   1677
#
# DeepAffinity: Interpretable Deep Learning of Compound-Protein Affinity
#   through Unified Recurrent and Convolutional Neural Networks   1687
#
# Enabling Pedestrian Safety using Computer Vision Techniques: A Case
#   Study of the 2018 Uber Inc. Self-driving Car Crash   1702
#
# Sparse Graph Codes for Non-adaptive Quantitative Group Testing   1712
#
# Non-adaptive Quantitative Group Testing Using Irregular Sparse Graph
#   Codes   1712
#
# Random Khatri-Rao-Product Codes for Numerically-Stable Distributed
#   Matrix Multiplication   1713
#
# Optimal Information Updating based on Value of Information   1714
#
# Capacity of Single-Server Single-Message Private Information Retrieval
#   with Private Coded Side Information   1715
#
# Multi-Server Private Information Retrieval with Coded Side Information   1715
#
# Private Information Retrieval with Private Coded Side Information: The
#   Multi-Server Case   1715
#
# Capacity of Single-Server Single-Message Private Information Retrieval
#   with Coded Side Information   1715
#
# A Robust Statistical method to Estimate the Intervention Effect with
#   Longitudinal Data   1718
#
# Explicit Motion Risk Representation   1738
#
# Benchmarking Tether-based UAV Motion Primitives   1739
#
# A Holomorphic Embedding Based Continuation Method for Identifying
#   Multiple Power Flow Solutions   1753
#
# Uncertainty Propagation in a Multiscale CALPHAD-Reinforced
#   Elastochemical Phase-field Model   1762
#
# Generating Labeled Flow Data from MAWILab Traces for Network Intrusion
#   Detection   1765
#
# A Systematic Approach to Incremental Redundancy over Erasure Channels   1774
#
# Experimental Design via Generalized Mean Objective Cost of Uncertainty   1784
#
# Multiple Linear Regression Haze-removal Model Based on Dark Channel
#   Prior   1786
#
# Cost-Aware Learning and Optimization for Opportunistic Spectrum Access   1791
#
# The Linear Capacity of Single-Server Individually-Private Information
#   Retrieval with Side Information   1800
#
# Capacity of Single-Server Single-Message Private Information Retrieval
#   with Coded Side Information   1800
#
# Capacity of Single-Server Single-Message Private Information Retrieval
#   with Private Coded Side Information   1800
#
# On the Capacity of Single-Server Multi-Message Private Information
#   Retrieval with Side Information   1800
#
# A Two-Stage Approach for Routing Multiple Unmanned Aerial Vehicles with
#   Stochastic Fuel Consumption   1826
#
# Anatomy of Scholarly Information Behavior Patterns in the Wake of
#   Academic Social Media Platforms   1827
#
# Residual-Based a posteriori error estimation for hp-adaptive finite
#   element methods for the Stokes equations   1828
#
# Multi-Label Adversarial Perturbations   1829
#
# Pseudo-Implicit Feedback for Alleviating Data Sparsity in Top-K
#   Recommendation   1830
#
# A Semi-Supervised and Inductive Embedding Model for Churn Prediction of
#   Large-Scale Mobile Games   1832
#
# Estimating Phase Duration for SPaT Messages   1852
#
# Towards Privacy-Preserving Visual Recognition via Adversarial Training:
#   A Pilot Study   1867
#
# On the Capacity of Single-Server Multi-Message Private Information
#   Retrieval with Side Information   1868
#
# Deep neural network initialization with decision trees   1875
#
# Drone Detection Using Depth Maps   1879
#
# Motion Planning for a UAV with a Straight or Kinked Tether   1882
#
# Estimating Achievable Range of Ground Robots Operating on Single Battery
#   Discharge for Operational Efficacy Amelioration   1883
#
# DES Science Portal: Computing Photometric Redshifts   1887
#
# Toward a language-theoretic foundation for planning and filtering   1892
#
# Edge-Enhanced Dual Discriminator Generative Adversarial Network for Fast
#   MRI with Parallel Imaging Using Multi-view Information   1903
#
# Noise-based logic gates by operations on the reference system   1906
#
# Benefits of V2V Communication for Autonomous and Connected Vehicles   1907
#
# New Results on Multilevel Diversity Coding with Secure Regeneration   1915
#
# Benchmarking Single Image Dehazing and Beyond   1924
#
# A Fast and Accurate Failure Frequency Approximation for $k$-Terminal
#   Reliability Systems   1925
#
# Personalized Saliency and its Prediction   1932
#
# Hierarchical Predictive Control Algorithms for Optimal Design and
#   Operation of Microgrids   1937
#
# Exploration of Graph Computing in Power System State Estimation   1943
#
# CIM/E Oriented Graph Database Model Architecture and Parallel Network
#   Topology Processing   1944
#
# A novel filter for accurate estimation of fluid pressure and fluid
#   velocity using poroelastography   1946
#
# Towards Explanation of DNN-based Prediction with Guided Feature
#   Inversion   1975
#
# Subspace Network: Deep Multi-Task Censored Regression for Modeling
#   Neurodegenerative Diseases   1978
#
# Numerical Software to Compute Newton Polytopes and Tropical Membership   1980
#
# DES Science Portal: Creating Science-Ready Catalogs   2002
#
# Infrastructure Enabled Autonomy: A Distributed Intelligence Architecture
#   for Autonomous Vehicles   2005
#
# A Distributed Hybrid Hardware-In-the-Loop Simulation framework for
#   Infrastructure Enabled Autonomy   2005
#
# Gröbner Bases of Neural Ideals   2013
#
# A Fast and Accurate Failure Frequency Approximation for $k$-Terminal
#   Reliability Systems   2022
#
# DeepAffinity: Interpretable Deep Learning of Compound-Protein Affinity
#   through Unified Recurrent and Convolutional Neural Networks   2029
#
# Adaptive Compute-and-Forward with Lattice Codes Over Algebraic Integers   2036
#
# New Results on Multilevel Diversity Coding with Secure Regeneration   2040
#
# Fundamental Limits of Coded Caching: From Uncoded Prefetching to Coded
#   Prefetching   2042
#
# Monocular Vision based Collaborative Localization for Micro Aerial
#   Vehicle Swarms   2043
#
# Compressed Covariance Estimation With Automated Dimension Learning   2050
#
# Accurate Learning or Fast Mixing? Dynamic Adaptability of Caching
#   Algorithms   2057
#
# Fundamental Limits of Cache-Aided Wireless BC: Interplay of
#   Coded-Caching and CSIT Feedback   2058
#
# Fundamental Limits of Coded Caching: From Uncoded Prefetching to Coded
#   Prefetching   2058
#
# On the Fundamental Limits of Coded Caching Systems with Restricted
#   Demand Types   2058
#
# Complete characterization of a class of privacy-preserving tracking
#   problems   2068
#
# A Systematic Approach to Incremental Redundancy over Erasure Channels   2088
#
# A Monetary Mechanism for Stabilizing Cooperative Data Exchange with
#   Selfish Users   2089
#
# Design, Generation, and Validation of Extreme Scale Power-Law Graphs   2090
#
# Optimum Search Schemes for Approximate String Matching Using
#   Bidirectional FM-Index   2114
#
# Assimilation of nearly turbulent Rayleigh-Bénard flow through
#   vorticity or local circulation measurements: a computational study   2156
#
# A Bayesian adaptive ensemble Kalman filter for sequential state and
#   parameter estimation   2179
#
# An Agent-based Modeling Framework for Sociotechnical Simulation of Water
#   Distribution Contamination Events   2190
#
# A Flocking-based Approach for Distributed Stochastic Optimization   2199
#
# Probabilistic Condition Number Estimates For Real Polynomial Systems I:
#   A Broader Family Of Distributions   2201
#
# Finite-Length Analysis of Spatially-Coupled Regular LDPC Ensembles on
#   Burst-Erasure Channels   2203
#
# Effects of Mn-substitution for Co on the structure and physical
#   properties of NayCoO2   2213
#
# Fast Block Linear System Solver Using Q-Learning Schduling for Unified
#   Dynamic Power System Simulations   2237
#
# Fast Monte Carlo Simulation of Dynamic Power Systems Under Continuous
#   Random Disturbances   2237
# Image Acquisition System Using On Sensor Compressed Sampling Technique   2243
#
# Particle Filters for Partially-Observed Boolean Dynamical Systems   2248
#
# Scalable Bayesian Variable Selection Using Nonlocal Prior Densities in
#   Ultrahigh-Dimensional Settings   2252
#
# Multiple Bracket Function, Stirling Number, and Lah Number Identities   2259
#
# A Deep Learning Framework for Short-term Power Load Forecasting   2265
#
# The method of shifted partial derivatives cannot separate the permanent
#   from the determinant   2278
#
# On the Use of the Observability Gramian for Partially Observed Robotic
#   Path Planning Problems   2284
#
# The Imaging of Small Perturbations in an Anisotropic Media   2294
#
# Attributed Network Embedding for Learning in a Dynamic Environment   2311
#
# Enhancement of Noisy Speech with Low Speech Distortion Based on
#   Probabilistic Geometric Spectral Subtraction   2324
#
# Enhancement of Noisy Speech exploiting a Gaussian Modeling based
#   Threshold and a PDF Dependent Thresholding Function   2324
#
# Enhancement of Noisy Speech Exploiting an Exponential Model Based
#   Threshold and a Custom Thresholding Function in Perceptual Wavelet Packet
#   Domain   2324
#
# On the Tradeoff Region of Secure Exact-Repair Regenerating Codes   2344
#
# A hybrid type Ia supernova with an early flash triggered by helium-shell
#   detonation   2351
#
# Robust Emotion Recognition from Low Quality and Low Bit Rate Video: A
#   Deep Learning Approach   2359
#
# Private Information Retrieval with Side Information   2361
#
# On the Capacity of Single-Server Multi-Message Private Information
#   Retrieval with Side Information   2361
#
# Single-Server Multi-Message Individually-Private Information Retrieval
#   with Side Information   2361
#
# Universally Weakly Secure Coset Coding Schemes for Minimum Storage
#   Regenerating (MSR) Codes   2363
#
# Approaching Capacity at High-Rates with Iterative Hard-Decision Decoding   2413
#
# A Comparative Study of Deep Learning Classification Methods on a Small
#   Environmental Microorganism Image Dataset (EMDS-6): from Convolutional Neural
#   Networks to Visual Transformers   2425
#
# On Sampling from Massive Graph Streams   2432
#
# On vanishing of Kronecker coefficients   2437
#
# Learning the LMP-Load Coupling From Data: A Support Vector Machine Based
#   Approach   2445
#
# Numerical computation of Galois groups   2485
#
# On the Tradeoff Region of Secure Exact-Repair Regenerating Codes   2494
#
# Universally Weakly Secure Coset Coding Schemes for Minimum Storage
#   Regenerating (MSR) Codes   2499
#
# Routing Unmanned Vehicles in GPS-Denied Environments   2502
#
# Routing Multiple Unmanned Vehicles in GPS-Denied Environments   2502
#
# Recommendation of Scholarly Venues Based on Dynamic User Interests   2562
#
# Neural Collaborative Filtering   2575
#
# Neural Graph Collaborative Filtering   2575
#
# Neural Collaborative Filtering Bandits via Meta Learning   2575
#
# Outer Product-based Neural Collaborative Filtering   2575
#
# Exponential decay of reconstruction error from binary measurements of
#   sparse signals   2588
#
# A System-Theoretic Clean Slate Approach to Provably Secure Ad Hoc
#   Wireless Networking   2596
#
# Theoretical Properties and Practical Performance of Fully Robust
#   One-Sided Cross-Validation   2613
#
# Reed-Muller Codes Achieve Capacity on Erasure Channels   2614
#
# Reed-Muller Codes Achieve Capacity on the Binary Erasure Channel under
#   MAP Decoding   2614
#
# Representation-Oblivious Error Correction by Natural Redundancy   2629
#
# Unconditionally secure credit/debit card chip scheme and physical
#   unclonable function   2630
#
# Detection of Cooperative Interactions in Logistic Regression Models   2685
#
# On dynamic algorithms for factorization invariants in numerical monoids   2688
#
# Joint Source-Channel Decoding of Polar Codes for Language-Based Source   2707
#
# High-Order AFEM for the Laplace-Beltrami Operator: Convergence Rates   2715
#
# Prognostics of Surgical Site Infections using Dynamic Health Data   2725
#
# Learning-Based Distributed Detection-Estimation in Sensor Networks with
#   Unknown Sensor Defects   2734
#
# Anatomical Region-Specific In Vivo Wireless Communication Channel
#   Characterization   2740
#
# Observation of the acceleration of light in a tapered optical fiber   2785
#
# Rigid Body Pose Estimation based on the Lagrange-d'Alembert Principle   2791
#
# Evolutionary Approaches to Optimization Problems in Chimera Topologies   2823
#
# Comparing the Bit-MAP and Block-MAP Decoding Thresholds of Reed-Muller
#   Codes on BMS Channels   2829
#
# Path Planning for Cooperative Routing of Air-Ground Vehicles   2832
#
# Formulations and algorithms for the multiple depot, fuel-constrained,
#   multiple vehicle routing problem   2841
#
# Reed-Muller Codes Achieve Capacity on Erasure Channels   2844
#
# Reed-Muller Codes Achieve Capacity on Erasure Channels   2844
#
# Crowdsourcing quality control for Dark Energy Survey images   2845
#
# Simulating thermal boundary conditions of spin-lattice models with
#   weighted averages   2846
#
# Graphlet Decomposition: Framework, Algorithms, and Applications   2852
#
# A System-Theoretic Clean Slate Approach to Provably Secure Ad Hoc
#   Wireless Networking   2856
#
# Multilevel Diversity Coding with Regeneration   2868
#
# New Results on Multilevel Diversity Coding with Secure Regeneration   2868
#
# Multilevel Diversity Coding with Regeneration: Separate Coding Achieves
#   the MBR Point   2868
#
# Multilevel Diversity Coding with Secure Regeneration: Separate Coding
#   Achieves the MBR Point   2868
#
# Current Injection Attack against the KLJN Secure Key Exchange   2882
#
# Overlapped List Successive Cancellation Approach for Hardware Efficient
#   Polar Code Decoder   2908
#
# Stochastic Block Coordinate Frank-Wolfe Algorithm for Large-Scale
#   Biological Network Alignment   2930
#
# Asymmetric Error Correction and Flash-Memory Rewriting using Polar Codes   2949
#
# New Results on Multilevel Diversity Coding with Secure Regeneration   2956
#
# Multilevel Diversity Coding with Regeneration: Separate Coding Achieves
#   the MBR Point   2956
#
# Multilevel Diversity Coding with Secure Regeneration: Separate Coding
#   Achieves the MBR Point   2956
#
# Key Exchange Trust Evaluation in Peer-to-Peer Sensor Networks with
#   Unconditionally Secure Key Exchange   2960
#
# Parallel inference for massive distributed spatial data using low-rank
#   models   2969
#
# Software for the Gale transform of fewnomial systems and a Descartes
#   rule for fewnomials   2983
#
# Duality between Feature Selection and Data Clustering   2989
#
# Distributed Bayesian Quickest Change Detection in Sensor Networks via
#   Two-layer Large Deviation Analysis   2999
#
# A Game-theoretic Perspective on Communication for Omniscience   3003
#
# Efficient Sampling for Better OSN Data Provisioning   3006
#
# Data Survivability in Networks of Mobile Robots in Urban Disaster
#   Environments   3022
#
# Belief-Grounded Networks for Accelerated Robot Learning under Partial
#   Observability   3025
#
# Resilient Time-Varying Formation Tracking for Mobile Robot Networks
#   under Deception Attacks on Positioning   3025
#
# Towards Provably Safe Mixed Transportation Systems with Human-driven and
#   Automated Vehicles   3048
#
# Simulating a Shared Register in a System that Never Stops Changing   3072
#
# ÆtherFlow: Principled Wireless Support in SDN   3081
#
# Nonlinear Reynolds equation for hydrodynamic lubrication   3135
#
# On the equivalence between two problems of asymmetry on convex bodies   3141
#
# On Minimizing the Average Packet Decoding Delay in Wireless Network
#   Coded Broadcast   3153
#
# A Switched Dynamical System Framework for Analysis of Massively Parallel
#   Asynchronous Numerical Algorithms   3164
#
# Lattices over Eisenstein Integers for Compute-and-Forward   3170
#
# Universal groups of intermediate growth and their invariant random
#   subgroups   3195
#
# A Dynamic Simulation-Optimization Model for Adaptive Management of Urban
#   Water Distribution System Contamination Threats   3197
#
# Cramer-Rao Lower Bound for Point Based Image Registration with
#   Heteroscedastic Error Model for Application in Single Molecule Microscopy   3198
#
# A High Reliability Asymptotic Approach for Packet Inter-Delivery Time
#   Optimization in Cyber-Physical Systems   3201
#
# Rank-Modulation Rewrite Coding for Flash Memories   3210
#
# On the Minimum Energy of Sending Gaussian Multiterminal Sources over the
#   Gaussian MAC   3216
# An Exact Algorithm for a Fuel-Constrained Autonomous Vehicle Path
#   Planning Problem   3217
#
# Multilevel Diversity Coding with Regeneration   3222
#
# New Results on Multilevel Diversity Coding with Secure Regeneration   3222
#
# Multilevel Diversity Coding with Regeneration: Separate Coding Achieves
#   the MBR Point   3222
#
# Multilevel Diversity Coding with Secure Regeneration: Separate Coding
#   Achieves the MBR Point   3222
#
# A Hebbian/Anti-Hebbian Neural Network for Linear Subspace Learning: A
#   Derivation from Multidimensional Scaling of Streaming Data   3235
#
# Enhanced usage of keys obtained by physical, unconditionally secure
#   distributions   3239
#
# A Unified Light Framework for Real-time Fault Detection of Freight Train
#   Images   3269
#
# Asynchronous Physical-Layer Network Coding with Quasi-Cyclic Codes   3288
#
# Distributed Kalman Filtering over Massive Data Sets: Analysis Through
#   Large Deviations of Random Riccati Equations   3326
#
# The Dark Side of Micro-Task Marketplaces: Characterizing Fiverr and
#   Automatically Detecting Crowdturfing   3327
#
# Analysis of an attenuator artifact in an experimental attack by
#   Gunn-Allison-Abbott against the Kirchhoff-law-Johnson-noise (KLJN) secure key
#   exchange system   3364
#
# On KLJN-based secure key distribution in vehicular communication
#   networks   3365
#
# Upper security bounds for coherent-one-way quantum key distribution   3377
#
# Finite-key security analysis for quantum key distribution with leaky
#   sources   3377
#
# Perfect random number generator is unnecessary for secure quantum key
#   distribution   3377
#
# Security analysis method for practical quantum key distribution with
#   arbitrary encoding schemes   3377
#
# A Proof of Threshold Saturation for Spatially-Coupled LDPC Codes on BMS
#   Channels   3394
#
# Threshold Saturation for Spatially-Coupled LDPC and LDGM Codes on BMS
#   Channels   3394
#
# Polynomial-Time Amoeba Neighborhood Membership and Faster Localized
#   Solving   3406
#
# A Hebbian/Anti-Hebbian Network for Online Sparse Dictionary Learning
#   Derived from Symmetric Matrix Factorization   3411
#
# A Hebbian/Anti-Hebbian Neural Network for Linear Subspace Learning: A
#   Derivation from Multidimensional Scaling of Streaming Data   3411
#
# Systematic Error-Correcting Codes for Rank Modulation   3421
#
# Opportunities for Network Coding: To Wait or Not to Wait   3455
#
# On the Minimum Energy of Sending Gaussian Multiterminal Sources over the
#   Gaussian MAC   3456
#
# Private Broadcasting over Independent Parallel Channels   3460
#
# tinyNBI: Distilling an API from essential OpenFlow abstractions   3471
#
# Securing vehicle communication systems by the KLJN key exchange protocol   3506
#
# On Feedback Vertex Set: New Measure and New Structures   3523
#
# A Low-Complexity Encoding of Quasi-Cyclic Codes Based on Galois Fourier
#   Transform   3524
#
# On the Relationships among Optimal Symmetric Fix-Free Codes   3526
#
# Newton polytopes and witness sets   3527
#
# Weakly Secure Regenerating Codes for Distributed Storage   3534
#
# Universally Weakly Secure Coset Coding Schemes for Minimum Storage
#   Regenerating (MSR) Codes   3534
#
# Moments and Root-Mean-Square Error of the Bayesian MMSE Estimator of
#   Classification Error in the Gaussian Model   3548
#
# Restricted Likelihood Ratio Tests for Linearity in Scalar-on-Function
#   Regression   3592
#
# A Mean Field Game Approach to Scheduling in Cellular Systems   3597
#
# Energy-Efficient Power Allocation for Secure Communications in
#   Large-Scale MIMO Relaying Systems   3600
#
# Energy Efficient Joint Resource Allocation and Power Control for D2D
#   Communications   3600
#
# Perspective -- On the thermodynamics of perfect unconditional security   3632
#
# On the security of the Kirchhoff-law-Johnson-noise (KLJN) communicator   3632
#
# Critical analysis of the Bennett-Riedel attack on secure cryptographic
#   key distributions via the Kirchhoff-law-Johnson-noise scheme   3632
#
# Critical analysis of the Bennett-Riedel attack on secure cryptographic
#   key distributions via the Kirchhoff-law-Johnson-noise scheme   3700
#
# Errors and their mitigation at the Kirchhoff-law-Johnson-noise secure
#   key exchange   3721
#
# Convergence of Weighted Min-Sum Decoding Via Dynamic Programming on
#   Trees   3730
#
# Symmetrical Multilevel Diversity Coding and Subset Entropy Inequalities   3738
#
# Eliminating Network Protocol Vulnerabilities Through Abstraction and
#   Systems Language Design   3774
#
# Scheduling Heterogeneous Real-Time Traffic over Fading Wireless Channels   3793
#
# Physical uncloneable function hardware keys utilizing
#   Kirchhoff-law-Johnson-noise secure key exchange and noise-based logic   3803
#
# Multilevel Coding Schemes for Compute-and-Forward   3831
#
# Multilevel Coding Schemes for Compute-and-Forward with Flexible Decoding   3831
#
# A Unifying Variational Perspective on Some Fundamental Information
#   Theoretic Inequalities   3839
#
# Throughput Maximization for the Gaussian Relay Channel with Energy
#   Harvesting Constraints   3840
#
# Numerical simulation of cylindrical solitary waves in periodic media   3845
#
# Nonstationary POT modelling of air pollution concentrations: Statistical
#   analysis of the traffic and meteorological impact   3849
#
# Impact of Temporary Fork on the Evolution of Mining Pools in Blockchain
#   Networks: An Evolutionary Game Analysis   3849
#
# On the Minimum Energy of Sending Gaussian Multiterminal Sources over the
#   Gaussian MAC   3851
#
# Rank-Modulation Rewrite Coding for Flash Memories   3859
#
# Energy-Efficient Resource Allocation for Device-to-Device Underlay
#   Communication   3860
#
# Energy-Efficient Resource Allocation for Wireless Powered Communication
#   Networks   3860
#
# Energy Efficient Resource Allocation for Time-Varying OFDMA Relay
#   Systems with Hybrid Energy Supplies   3860
#
# Energy-efficient Resource Allocation for Mobile Edge Computing Aided by
#   Multiple Relays   3860
#
# Energy-Efficient Communication in the Presence of Synchronization Errors   3864
#
# Code Design for the Noisy Slepian-Wolf Problem   3866
#
# Enhanced secure key exchange systems based on the Johnson-noise scheme   3877
#
# First-Passage Time and Large-Deviation Analysis for Erasure Channels
#   with Memory   3895
#
# Gaussian Assumption: the Least Favorable but the Most Useful   3918
#
# Optimal computation of symmetric Boolean functions in Tree networks   3929
#
# Optimal Computation of Symmetric Boolean Functions in Collocated
#   Networks   3929
#
# Trajectory Codes for Flash Memory   3930
#
# On the Relationships among Optimal Symmetric Fix-Free Codes   3938
#
# Dynamics of Oscillators Coupled by a Medium with Adaptive Impact   3956
#
# Secure Symmetrical Multilevel Diversity Coding   3959
#
# Nonuniform Codes for Correcting Asymmetric Errors in Data Storage   3973
#
# New Results on Multiple-Input Multiple-Output Broadcast Channels with
#   Confidential Messages   3976
#
# Holographic algorithms without matchgates   3993
#
# Normal art galleries: wall in - all in   3994
#
# Joint Power and Admission Control based on Channel Distribution
#   Information: A Novel Two-Timescale Approach   4004
#
# Parameterized Algorithms for the Maximum Agreement Forest Problem on
#   Multiple Rooted Multifurcating Trees   4005
#
# Information theoretic security by the laws of classical physics   4015
#
# Noise based logic: why noise? A comparative study of the necessity of
#   randomness out of orthogonality   4049
#
# Spectra for the product of Gaussian noises   4054
#
# Joint Compute and Forward for the Two Way Relay Channel with Spatially
#   Coupled LDPC Codes   4057
#
# Lattices over Eisenstein Integers for Compute-and-Forward   4108
#
# A new sufficient condition for sum-rate tightness in quadratic Gaussian
#   multiterminal source coding   4144
#
# A Simple Proof of Threshold Saturation for Coupled Scalar Recursions   4160
#
# A Simple Proof of Threshold Saturation for Coupled Vector Recursions   4160
#
# Boolean Satisfiability using Noise Based Logic   4173
#
# On the Achievable Rates of the Diamond Relay Channel with Conferencing
#   Links   4176
#
# Approaching Capacity at High-Rates with Iterative Hard-Decision Decoding   4182
#
# Systematic Error-Correcting Codes for Rank Modulation   4189
#
# Optimal Power Allocation for Outage Minimization in Fading Channels with
#   Energy Harvesting Constraints   4209
#
# New noise-based logic representations to avoid some problems with time
#   complexity   4214
# A Factor Graph Approach to Clock Offset Estimation in Wireless Sensor
#   Networks   4255
#
# Secure Network Coding for Wiretap Networks of Type II   4267
#
# Learning-Based Distributed Detection-Estimation in Sensor Networks with
#   Unknown Sensor Defects   4274
#
# Data-Driven Distributed State Estimation and Behavior Modeling in Sensor
#   Networks   4274
#
# Optimal Function Computation in Directed and Undirected Graphs   4282
#
# A Simple Proof of Threshold Saturation for Coupled Scalar Recursions   4298
#
# A Simple Proof of Threshold Saturation for Coupled Vector Recursions   4298
#
# Noise based logic: why noise? A comparative study of the necessity of
#   randomness out of orthogonality   4319
#
# Noncooperative Games for Autonomous Consumer Load Balancing over Smart
#   Grid   4361

# %% [markdown]
# #### arxiv_pub_id = []
# arxiv_pubs_clean = []
# for i in arxiv_publications:
#     if i['id'] not in arxiv_pub_id:
#         arxiv_pubs_clean.append(i)
#         arxiv_pub_id.append(i['id'])
# vizfile = open('vizfile_2.ris','w')
# for article in arxiv_pubs_clean:
#     vizfile.write('\nTY  - JOUR')
#     Author = refine_texts(article['author'])
#     vizfile.write('\nAU  - %s'%Author)
#     vizfile.write('\nPY  - %s'%article['published'][:4])
#     Title = refine_texts(article['title'])
#     vizfile.write('\nTI  - %s'%Title)
#     for tags in article['tags']:
#         if tags['term'] in Categories.keys():
#             vizfile.write('\nKW  - %s'%Categories[tags['term']])
#         else:
#             continue
#     vizfile.write('\nER  - \n')
# vizfile.close()
